# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
# Read the CSV file
df = pd.read_csv('books.csv')

# Show the first few rows
df.head()
# Out:
#                                    Title    Price
# 0                   A Light in the Attic  Â£51.77
# 1                     Tipping the Velvet  Â£53.74
# 2                             Soumission  Â£50.10
# 3                          Sharp Objects  Â£47.82
# 4  Sapiens: A Brief History of Humankind  Â£54.23

# %%
print(df['Price'].head())
print(df['Price'].dtype)
# Out:
# 0    Â£51.77
# 1    Â£53.74
# 2    Â£50.10
# 3    Â£47.82
# 4    Â£54.23
# Name: Price, dtype: object
# object

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0363c7cd-1ac4-4764-b602-112a1fa3618c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0363c7cd-1ac4-4764-b602-112a1fa3618c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('books.csv')

# Remove all unwanted characters from 'Price'
df['Price'] = df['Price'].astype(str).str.replace(r'[^0-9.]', '', regex=True).astype(float)

# Check the output
print(df['Price'].head())
# Out:
# 0    51.77
# 1    53.74
# 2    50.10
# 3    47.82
# 4    54.23
# Name: Price, dtype: float64

# %%
df.head()
# Out:
#                                    Title  Price
# 0                   A Light in the Attic  51.77
# 1                     Tipping the Velvet  53.74
# 2                             Soumission  50.10
# 3                          Sharp Objects  47.82
# 4  Sapiens: A Brief History of Humankind  54.23

# %%
df['Price'] = df['Price'].astype(str).str.replace(r'[^0-9.]', '', regex=True).astype(float)

# %%
print(df['Price'].head())
# Out:
# 0    51.77
# 1    53.74
# 2    50.10
# 3    47.82
# 4    54.23
# Name: Price, dtype: float64

# %%
top_books = df.sort_values(by='Price', ascending=False).head(10)

plt.figure(figsize=(10,6))
plt.barh(top_books['Title'], top_books['Price'], color='skyblue')
plt.xlabel('Price (£)')
plt.title('Top 10 Most Expensive Books')
plt.gca().invert_yaxis()  # highest on top
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Price'], bins=10, color='orange', edgecolor='black')
plt.title('Distribution of Book Prices')
plt.xlabel('Price (£)')
plt.ylabel('Number of Books')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df['Price'], vert=False)
plt.title('Box Plot of Book Prices')
plt.xlabel('Price (£)')
plt.show()
